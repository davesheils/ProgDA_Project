# %%
# First step - import libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Second step - load data from CSV

df2 = pd.read_csv('GraduateSampleNua2017.csv')
df2.head()
# Out:
#    Unnamed: 0 Year of Entry Gender Long LC Points Range 1 LC Points Range 2  \
# 0           0     2012/2013      Female       305 to <355     medium points
# 1           1     2012/2013      Female       305 to <355     medium points
# 2           2     2012/2013      Female       405 to <455       high points
# 3           3     2012/2013        Male       455 to <505       high points
# 4           4     2012/2013      Female       205 to <255     medium points
#
#   DEIS_OR_FEE_PAYING_DESC High Qual Desc Age Group Institute Type  \
# 0                 Neither            NaN        19       Colleges
# 1                 Neither            NaN        18       Colleges
# 2                 Neither            NaN        19       Colleges
# 3                 Neither            NaN        19       Colleges
# 4                 Neither            NaN        22       Colleges
#
#    Year of Graduation       Non Standard Award Desc       Field of Study  \
# 0                2017  Undergraduate Honours Degree  Arts and humanities
# 1                2017  Undergraduate Honours Degree  Arts and humanities
# 2                2017  Undergraduate Honours Degree  Arts and humanities
# 3                2017  Undergraduate Honours Degree  Arts and humanities
# 4                2017  Undergraduate Honours Degree  Arts and humanities
#
#                     Grade Desc  Score  Number of years  \
# 0  2nd Class Honours (Grade 2)   54.5                4
# 1  2nd Class Honours (Grade 2)   54.5                4
# 2            1st Class Honours   85.0                4
# 3  2nd Class Honours (Grade 2)   54.5                4
# 4            3rd Class Honours   44.5                4
#
#   Institute Alternative Name
# 0                  College 5
# 1                  College 5
# 2                  College 5
# 3                  College 5
# 4                  College 5

# %%
# what is the overall distribution of grades of this dataset?
# Please remember that we do not have actual scores, only grades, 
# replaced with the median score of the grade (e.g 85 for a first etc)

plt.figure(figsize=(12, 8))
plt.hist(df2['Grade Desc'])
plt.show()

# %%
# Would it be accurate to describe this as a normal distribution?

# What is the standard deviation of the grade Desc column?

df2.describe()
# Out:
#          Unnamed: 0  Year of Graduation         Score  Number of years
# count  19581.000000             19581.0  19581.000000     19581.000000
# mean   10029.585261              2017.0     64.980389         3.145907
# std     5827.946811                 0.0     11.884014         0.353022
# min        0.000000              2017.0     44.500000         3.000000
# 25%     5005.000000              2017.0     54.500000         3.000000
# 50%     9930.000000              2017.0     64.500000         3.000000
# 75%    14946.000000              2017.0     64.500000         3.000000
# max    20642.000000              2017.0     85.000000         4.000000

# %%
# So  .... lets try to recreate the above by using numpy.random.normal, using the count, mean and std deviation, as derived
# from the above 

# To recap, The numpy.random.normal() function draws random samples from a normal (Gaussian) distribution.

# The function takes 3 values:

 
#   loc: the mean or "centre" of the distribution
#   scale: the standard deviation of the distribution
#   size: the number of samples


x = np.random.normal(64.980389, 11.884014, 19581)
plt.hist(x)
plt.show()

# %% [markdown]
# Clearly, a normal distribution is an inappropriate model here.

# %% [markdown]
# Lets investigate the distribution of grades by gender and see if there is any variation in the pattern ...

# %%
female = df2[df2['Gender Long'] == 'Female']
male = df2[df2['Gender Long'] == 'Male']

plt.figure(figsize=(15, 15)) # This sets the size of the individual plots 


plt.subplot(2,1,1)
plt.hist(female['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - Female")

plt.subplot(2,1,2)
plt.hist(male['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - Male")

plt.show()

# %% [markdown]
# From the above, there is no significcant variation in the distribution of grades by gender (if anything, there seems  to be a small variance within the two second class honours grades, with the females doing slighlty better here with 50% of them getting a 2:1 compared to 42% of males. Nevertheless, there is only a 1% difference in terms of Firsts and Third class honours.

# %%
# What about distribution by type of college?
University = df2[df2['Institute Type'] == 'Universities']
Colleges = df2[df2['Institute Type'] == 'Institutes of Technology']
IOT = df2[df2['Institute Type'] == 'Colleges']

plt.figure(figsize=(15, 15)) # This sets the size of the individual plots 

plt.subplot(3,1,1)
plt.hist(University['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - University")

plt.subplot(3,1,2)
plt.hist(Colleges['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - Colleges")

plt.subplot(3,1,3)
plt.hist(IOT['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - IOTs")



plt.show()

# %% [markdown]
# There are some samll variances here. For example, the colleges sector have a lower proportion of firsts, but proportionally the greater number of 2:1s and indeed the largest proportionally of combined second class honours.
#
# Nevertheless, the broad shape of the distribution is the same for each sector.

# %%
# LC points range

high = df2[df2['LC Points Range 2'] == 'high points']
medium = df2[df2['LC Points Range 2'] == 'medium points']
low = df2[df2['LC Points Range 2'] == 'low points']

plt.figure(figsize=(15, 15)) # This sets the size of the individual plots 

plt.subplot(3,1,1)
plt.hist(high['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - High LC Points")

plt.subplot(3,1,2)
plt.hist(medium['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - Medium LC")

plt.subplot(3,1,3)
plt.hist(low['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - Low LC")



plt.show()

# %%
high
# Out:
#        Unnamed: 0 Year of Entry Gender Long LC Points Range 1  \
# 2               2     2012/2013      Female       405 to <455
# 3               3     2012/2013        Male       455 to <505
# 8               8     2013/2014      Female       455 to <505
# 10             10     2013/2014      Female       405 to <455
# 13             13     2013/2014      Female       405 to <455
# 18             18     2013/2014        Male       405 to <455
# 19             19     2013/2014      Female       405 to <455
# 23             23     2013/2014        Male       455 to <505
# 26             26     2013/2014        Male       405 to <455
# 58             60     2012/2013        Male       455 to <505
# 64             66     2012/2013      Female       405 to <455
# 70             72     2012/2013        Male       405 to <455
# 74             77     2013/2014        Male       405 to <455
# 96            105     2013/2014        Male       405 to <455
# 97            106     2013/2014      Female       455 to <505
# 103           112     2013/2014      Female       405 to <455
# 104           113     2013/2014      Female       405 to <455
# 108           117     2013/2014      Female       405 to <455
# 110           119     2013/2014      Female       455 to <505
# 112           121     2013/2014      Female       405 to <455
# 116           125     2013/2014        Male       405 to <455
# 118           127     2013/2014        Male       405 to <455
# 121           130     2013/2014        Male       405 to <455
# 122           131     2013/2014      Female       405 to <455
# 125           134     2013/2014      Female       455 to <505
# 126           135     2013/2014      Female       405 to <455
# 128           137     2013/2014      Female       455 to <505
# 130           139     2013/2014        Male       405 to <455
# 135           144     2013/2014      Female       405 to <455
# 138           147     2013/2014      Female       405 to <455
# ...           ...           ...         ...               ...
# 19420       20482     2013/2014        Male       405 to <455
# 19429       20491     2013/2014      Female       505 to <555
# 19434       20496     2013/2014        Male       405 to <455
# 19436       20498     2013/2014        Male       405 to <455
# 19444       20506     2013/2014        Male       405 to <455
# 19448       20510     2013/2014      Female       405 to <455
# 19456       20518     2013/2014      Female       405 to <455
# 19458       20520     2013/2014        Male       405 to <455
# 19463       20525     2013/2014      Female       405 to <455
# 19464       20526     2013/2014        Male       405 to <455
# 19475       20537     2013/2014        Male       405 to <455
# 19477       20539     2013/2014      Female       405 to <455
# 19478       20540     2013/2014        Male       405 to <455
# 19480       20542     2013/2014      Female       405 to <455
# 19485       20547     2013/2014        Male       405 to <455
# 19491       20553     2013/2014        Male       405 to <455
# 19498       20560     2013/2014      Female       405 to <455
# 19503       20565     2013/2014        Male       405 to <455
# 19505       20567     2013/2014        Male       405 to <455
# 19522       20584     2013/2014      Female       405 to <455
# 19528       20590     2013/2014        Male       405 to <455
# 19532       20594     2013/2014      Female       405 to <455
# 19537       20599     2013/2014        Male       455 to <505
# 19549       20611     2013/2014        Male       505 to <555
# 19552       20614     2013/2014        Male       405 to <455
# 19555       20617     2013/2014        Male       405 to <455
# 19561       20623     2013/2014        Male       455 to <505
# 19564       20626     2013/2014      Female       405 to <455
# 19571       20633     2013/2014        Male       405 to <455
# 19580       20642     2013/2014      Female       405 to <455
#
#       LC Points Range 2 DEIS_OR_FEE_PAYING_DESC  \
# 2           high points                 Neither
# 3           high points                 Neither
# 8           high points                 Neither
# 10          high points                    Deis
# 13          high points                 Neither
# 18          high points                 Neither
# 19          high points              Fee Paying
# 23          high points                 Unknown
# 26          high points              Fee Paying
# 58          high points                 Neither
# 64          high points                 Unknown
# 70          high points                 Neither
# 74          high points                    Deis
# 96          high points                 Neither
# 97          high points              Fee Paying
# 103         high points                    Deis
# 104         high points                    Deis
# 108         high points                 Neither
# 110         high points                 Unknown
# 112         high points                 Neither
# 116         high points                 Neither
# 118         high points                 Unknown
# 121         high points                 Neither
# 122         high points                 Neither
# 125         high points                 Neither
# 126         high points                 Neither
# 128         high points                 Neither
# 130         high points                 Neither
# 135         high points                 Neither
# 138         high points                 Neither
# ...                 ...                     ...
# 19420       high points                 Unknown
# 19429       high points                 Neither
# 19434       high points                    Deis
# 19436       high points                 Neither
# 19444       high points                 Neither
# 19448       high points                 Neither
# 19456       high points                 Neither
# 19458       high points                 Neither
# 19463       high points                 Neither
# 19464       high points                 Neither
# 19475       high points                    Deis
# 19477       high points                    Deis
# 19478       high points                 Neither
# 19480       high points                 Neither
# 19485       high points                 Neither
# 19491       high points                 Neither
# 19498       high points                 Neither
# 19503       high points                 Neither
# 19505       high points                 Neither
# 19522       high points                 Neither
# 19528       high points                 Neither
# 19532       high points                 Neither
# 19537       high points                 Neither
# 19549       high points                 Neither
# 19552       high points                 Neither
# 19505                                Arts and humanities
# 19522                                 Health and welfare
# 19528  Information and Communication Technologies (ICTs)
# 19532                                Arts and humanities
# 19537                   Business, administration and law
# 19549  Information and Communication Technologies (ICTs)
# 19552        Social sciences, journalism and information
# 19555    Agriculture, forestry, fisheries and veterinary
# 19561        Engineering, manufacturing and construction
# 19564                                           Services
# 19571    Agriculture, forestry, fisheries and veterinary
# 19580                                 Health and welfare
#
#                         Grade Desc  Score  Number of years  \
# 2                1st Class Honours   85.0                4
# 3      2nd Class Honours (Grade 2)   54.5                4
# 8                1st Class Honours   85.0                3
# 10     2nd Class Honours (Grade 1)   64.5                3
# 13               1st Class Honours   85.0                3
# 18     2nd Class Honours (Grade 2)   54.5                3
# 19     2nd Class Honours (Grade 1)   64.5                3
# 23               1st Class Honours   85.0                3
# 26               1st Class Honours   85.0                3
# 58     2nd Class Honours (Grade 1)   64.5                4
# 64     2nd Class Honours (Grade 1)   64.5                4
# 70     2nd Class Honours (Grade 2)   54.5                4
# 74     2nd Class Honours (Grade 2)   54.5                3
# 96               3rd Class Honours   44.5                3
# 97     2nd Class Honours (Grade 1)   64.5                3
# 103    2nd Class Honours (Grade 1)   64.5                3
# 104              1st Class Honours   85.0                3
# 108    2nd Class Honours (Grade 1)   64.5                3
# 110    2nd Class Honours (Grade 1)   64.5                3
# 112    2nd Class Honours (Grade 2)   54.5                3
# 116    2nd Class Honours (Grade 1)   64.5                3
# 118    2nd Class Honours (Grade 1)   64.5                3
# 121              1st Class Honours   85.0                3
# 122    2nd Class Honours (Grade 1)   64.5                3
# 125    2nd Class Honours (Grade 1)   64.5                3
# 126    2nd Class Honours (Grade 1)   64.5                3
# 128              1st Class Honours   85.0                3
# 130              1st Class Honours   85.0                3
# 135    2nd Class Honours (Grade 1)   64.5                3
# 138    2nd Class Honours (Grade 1)   64.5                3
# ...                            ...    ...              ...
# 19420            1st Class Honours   85.0                3
# 19429  2nd Class Honours (Grade 1)   64.5                3
# 19434  2nd Class Honours (Grade 1)   64.5                3
# 19436  2nd Class Honours (Grade 1)   64.5                3
# 19444  2nd Class Honours (Grade 2)   54.5                3
# 19448  2nd Class Honours (Grade 1)   64.5                3
# 19456  2nd Class Honours (Grade 2)   54.5                3
# 19458            3rd Class Honours   44.5                3
# 19463  2nd Class Honours (Grade 1)   64.5                3
# 19464  2nd Class Honours (Grade 1)   64.5                3
# 19475  2nd Class Honours (Grade 1)   64.5                3
# 19477  2nd Class Honours (Grade 1)   64.5                3
# 19478  2nd Class Honours (Grade 1)   64.5                3
# 19480  2nd Class Honours (Grade 1)   64.5                3
# 19485  2nd Class Honours (Grade 1)   64.5                3
# 19491  2nd Class Honours (Grade 2)   54.5                3
# 19498  2nd Class Honours (Grade 1)   64.5                3
# 19503  2nd Class Honours (Grade 1)   64.5                3
# 19505  2nd Class Honours (Grade 1)   64.5                3
# 19522            1st Class Honours   85.0                3
# 19528  2nd Class Honours (Grade 1)   64.5                3
# 19532  2nd Class Honours (Grade 1)   64.5                3
# 19537            3rd Class Honours   44.5                3
# 19549            1st Class Honours   85.0                3
# 19552  2nd Class Honours (Grade 1)   64.5                3
# 19555  2nd Class Honours (Grade 1)   64.5                3
# 19561            1st Class Honours   85.0                3
# 19564  2nd Class Honours (Grade 1)   64.5                3
# 19571  2nd Class Honours (Grade 2)   54.5                3
# 19580  2nd Class Honours (Grade 1)   64.5                3
#
#       Institute Alternative Name
# 2                      College 5
# 3                      College 5
# 8                      College 5
# 10                     College 5
# 13                     College 5
# 18                     College 5
# 19                     College 5
# 23                     College 5
# 26                     College 5
# 58                   Institute 6
# 64                   Institute 6
# 70                   Institute 6
# 74                   Institute 6
# 96                   Institute 6
# 97                   Institute 6
# 103                  Institute 6
# 104                  Institute 6
# 108                  Institute 6
# 110                  Institute 6
# 112                  Institute 6
# 116                  Institute 6
# 118                  Institute 6
# 121                  Institute 6
# 122                  Institute 6
# 125                  Institute 6
# 126                  Institute 6
# 128                  Institute 6
# 130                  Institute 6
# 135                  Institute 6
# 138                  Institute 6
# ...                          ...
# 19420                Institute 4
# 19429                Institute 4
# 19434                Institute 4
# 19436                Institute 4
# 19444                Institute 4
# 19448                Institute 4
# 19456                Institute 4
# 19458                Institute 4
# 19463                Institute 4
# 19464                Institute 4
# 19475                Institute 4
# 19477                Institute 4
# 19478                Institute 4
# 19480                Institute 4
# 19485                Institute 4
# 19491                Institute 4
# 19498                Institute 4
# 19503                Institute 4
# 19505                Institute 4
# 19522                Institute 4
# 19528                Institute 4
# 19532                Institute 4
# 19537                Institute 4
# 19549                Institute 4
# 19552                Institute 4
# 19555                Institute 4
# 19561                Institute 4
# 19564                Institute 4
# 19571                Institute 4
# 19580                Institute 4
#
# [8773 rows x 16 columns]

# %% [markdown]
# Here we start to see a departure - for those students entering with low LC points, they are the only group where the proportion of 3rds is greater than than of those with firsts. **Note that they are a relatively low component of this cohort**
#
# If anything, those with mediumm and low points start to approxiamte a normal distribution, whereas those with high points conform to the distribution of grades in the HE sector as a whole.

# %%
# Finally, type of school

deis = df2[df2['DEIS_OR_FEE_PAYING_DESC'] == 'Deis']
fee = df2[df2['DEIS_OR_FEE_PAYING_DESC'] == 'Fee Paying']
neither = df2[df2['DEIS_OR_FEE_PAYING_DESC'] == 'Neither']
unknown = df2[df2['DEIS_OR_FEE_PAYING_DESC'] == 'Unknown']



# Unknowns excluded from this 

plt.figure(figsize=(15, 20)) # This sets the size of the individual plots 

plt.subplot(4,1,1)
plt.hist(deis['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - Deis School")

plt.subplot(4,1,2)
plt.hist(fee['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - Fee paying schools")

plt.subplot(4,1,3)
plt.hist(neither['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - neither")

plt.subplot(4,1,4)
plt.hist(unknown['Grade Desc']) 
plt.xlabel("distribution of grades")
plt.title("Distribution of grades - Unknown")

plt.show()

# %% [markdown]
# Deis get lowest proportion of firsts. Interestingly the highest prop of thirds and lowest seconds (combined) is from teh "unknown" category
